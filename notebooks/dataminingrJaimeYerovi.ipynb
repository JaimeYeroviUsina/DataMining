# %%
# This R environment comes with many helpful analytics packages installed
# It is defined by the kaggle/rstats Docker image: https://github.com/kaggle/docker-rstats
# For example, here's a helpful package to load
library(dplyr)
library(tidyverse) # metapackage of all tidyverse packages
library(modeest)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

list.files(path = "../input")

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# [1] "echocardiogram-uci"        "network"
# [3] "new-york-air-quality"      "new-york-city-air-quality"
# [5] "servicesarea"

# %% [markdown]
# Data Mining
#
# 2. Hands On: Data Import and Manipulation

# %%
#Create an array of 10 random integers between 1 and 100, and then calculate the mean and
#standard deviation of the array
a<-c(3,5,8,23,45,67,89,09,76,23)
a <- array(a)
mean(a)
sd(a)
# Out:
# [1] 34.8
# [1] 32.21042

# %%
b <- runif(10,min=1,max=100)
c<-sample(1:100,10)
b
c
mean(c)
sd(c)
# Out:
#  [1] 30.05431 10.68022 40.26359 47.40515 43.05330 76.99940 13.36698 53.08541
#  [9] 93.45793 35.88639
#  [1] 91 26 82 97 76 19 68  9 42  4
# [1] 51.4
# [1] 35.4219

# %%
#Create a 2-dimensional array of 3 rows and 4 columns with random integer values. Then, calculate
#the sum of each row and column.
D<-matrix(sample(1:100,12,replace=TRUE),ncol=4)
D
E<- rowSums(D)
E
F<- colSums(D)
F
# Out:
#      [,1] [,2] [,3] [,4]
# [1,]  6   59   55   40
# [2,] 23   29   53   84
# [3,]  9   64   56   19
# [1] 160 189 148
# [1]  38 152 164 143

# %%
#Greate a DataFrame with 3 columns: "Name", "Age", and "City". Add at least 5 rows of data to the
#DataFrame. Then, filter the DataFrame to only include rows where the person's age is greater than
#or equal to 30.

f <- data.frame(
"Name" =  as.character(c("Andres", "Daniel", "Carlos", "Dylan","Jaime")),
"Age" = c(23,24,25,32,30),
"City" = as.character(c("Quito", "Cuenca", "Guayaquil", "Quito","Tulcan"))
)

filter(df,Age > 30)
# Out:
#   Name  Age City
# 1 Dylan 32  Quito

# %%
#Load a CSV file into a DataFrame and then calculate the mean, median, and mode of one of the
#columns in the DataFrame.

data <- read.csv ("/kaggle/input/network/Network.csv")

df <- data.frame(data)

mean(df$VersionNum) 
median(df$VersionNum) 
frecuencias <- data.frame(table(df$VersionNum))
moda <- frecuencias[which.max(frecuencias$Freq),1]

paste( moda)
# Out:
# [1] 5.924908
# [1] 5
# [1] "3"

# %%
#Create a scatter plot of random x and y values between 1 and 100.

x<-sample(1:100,10)
y<-sample(1:100,10)

plot(x, y, pch = 19, col = "black")

# %%
#Load a CSV file into a DataFrame and then create a line chart of one of the columns in the DataFrame.

data <- read.csv ("/kaggle/input/network/Network.csv")
df <- data.frame(data)

x<-df$VersionNum
y<-df$IssuerId2

plot(x, y, type = "l")

# %% [markdown]
# 3. Data Import
#
#
# The Echocardiogram data set in the UCI Machine Learning repository contains information on a set of
# patients that suffered heart attacks at some point in the past.

# %%
#Download the Echocardiogram data set and import it to a data frame. Read the information on the
#data set and find out how missing values are represented and make sure that they are properly
#represented.

data <- read.csv("/kaggle/input/echocardiogram-uci/echocardiogram.csv")

df <- data.frame(data)

is.na(df)
# Out:
#       survival alive age   pericardialeffusion fractionalshortening epss  lvdd
#  [1,] FALSE    FALSE FALSE FALSE               FALSE                FALSE FALSE
#  [2,] FALSE    FALSE FALSE FALSE               FALSE                FALSE FALSE
#  [3,] FALSE    FALSE FALSE FALSE               FALSE                FALSE FALSE
#  [4,] FALSE    FALSE FALSE FALSE               FALSE                FALSE FALSE
#  [5,] FALSE    FALSE FALSE FALSE               FALSE                FALSE FALSE
#  [6,] FALSE    FALSE FALSE FALSE               FALSE                FALSE FALSE
#  [7,] FALSE    FALSE FALSE FALSE               FALSE                FALSE FALSE
#  [8,] FALSE    FALSE FALSE FALSE               FALSE                FALSE FALSE
#  [9,] FALSE    FALSE FALSE FALSE               FALSE                FALSE FALSE
# [10,] FALSE    FALSE FALSE FALSE               FALSE                FALSE FALSE
# [11,] FALSE    FALSE FALSE FALSE               FALSE                FALSE FALSE
# ...

# %%
#Assign the attributes with meaningful names. You can look for this information on the same webpage.

data <- read.csv("/kaggle/input/echocardiogram-uci/echocardiogram.csv")

df <- data.frame(data)

colnames(df)[13] <- "aliveatAux"
colnames(df)[8] <- "wallmotionScore"
colnames(df)[9] <- "wallmotionIndex"

df
# Out:
#     survival alive age    pericardialeffusion fractionalshortening epss   lvdd
# 1   11.00    0     71.000 0                   0.260                 9.000 4.600
# 2   19.00    0     72.000 0                   0.380                 6.000 4.100
# 3   16.00    0     55.000 0                   0.260                 4.000 3.420
# 4   57.00    0     60.000 0                   0.253                12.062 4.603
# 5   19.00    1     57.000 0                   0.160                22.000 5.750
# 6   26.00    0     68.000 0                   0.260                 5.000 4.310
# 7   13.00    0     62.000 0                   0.230                31.000 5.430
# 8   50.00    0     60.000 0                   0.330                 8.000 5.250
# 9   19.00    0     46.000 0                   0.340                 0.000 5.090
# 10  25.00    0     54.000 0                   0.140                13.000 4.490
# 11  10.00    1     77.000 0                   0.130                16.000 4.230
# ...

# %%
#According to that same information, is there any redundant or irrelevant attribute that you can
#remove? Remove them

data <- read.csv("/kaggle/input/echocardiogram-uci/echocardiogram.csv")

df <- data.frame(data)

df ["aliveat1"] <- list (NULL)

df
# Out:
#     survival alive age    pericardialeffusion fractionalshortening epss   lvdd
# 1   11.00    0     71.000 0                   0.260                 9.000 4.600
# 2   19.00    0     72.000 0                   0.380                 6.000 4.100
# 3   16.00    0     55.000 0                   0.260                 4.000 3.420
# 4   57.00    0     60.000 0                   0.253                12.062 4.603
# 5   19.00    1     57.000 0                   0.160                22.000 5.750
# 6   26.00    0     68.000 0                   0.260                 5.000 4.310
# 7   13.00    0     62.000 0                   0.230                31.000 5.430
# 8   50.00    0     60.000 0                   0.330                 8.000 5.250
# 9   19.00    0     46.000 0                   0.340                 0.000 5.090
# 10  25.00    0     54.000 0                   0.140                13.000 4.490
# 11  10.00    1     77.000 0                   0.130                16.000 4.230
# ...

# %%
#Is there any data type change that you find useful? Perform it

data <- read.csv("/kaggle/input/echocardiogram-uci/echocardiogram.csv")

df <- data.frame(data)

#df["pericardialeffusion"]<- list(as.double())

df$pericardialeffusion <- as.double(df$pericardialeffusion)

df
# Out:
#     survival alive age    pericardialeffusion fractionalshortening epss   lvdd
# 1   11.00    0     71.000 0                   0.260                 9.000 4.600
# 2   19.00    0     72.000 0                   0.380                 6.000 4.100
# 3   16.00    0     55.000 0                   0.260                 4.000 3.420
# 4   57.00    0     60.000 0                   0.253                12.062 4.603
# 5   19.00    1     57.000 0                   0.160                22.000 5.750
# 6   26.00    0     68.000 0                   0.260                 5.000 4.310
# 7   13.00    0     62.000 0                   0.230                31.000 5.430
# 8   50.00    0     60.000 0                   0.330                 8.000 5.250
# 9   19.00    0     46.000 0                   0.340                 0.000 5.090
# 10  25.00    0     54.000 0                   0.140                13.000 4.490
# 11  10.00    1     77.000 0                   0.130                16.000 4.230
# ...

# %% [markdown]
# 4. Data Manipulation
#
# Load the airquality data set regarding a set of New York Air Quality Measurements.

# %%
#For which attributes are there missing values?

data <- read.csv("/kaggle/input/new-york-air-quality/airquality.csv")

df <- data.frame(data)

is.na(df)
# Out:
#       Ozone Solar.R Wind  Temp  Month Day
#  [1,] FALSE FALSE   FALSE FALSE FALSE FALSE
#  [2,] FALSE FALSE   FALSE FALSE FALSE FALSE
#  [3,] FALSE FALSE   FALSE FALSE FALSE FALSE
#  [4,] FALSE FALSE   FALSE FALSE FALSE FALSE
#  [5,]  TRUE  TRUE   FALSE FALSE FALSE FALSE
#  [6,] FALSE  TRUE   FALSE FALSE FALSE FALSE
#  [7,] FALSE FALSE   FALSE FALSE FALSE FALSE
#  [8,] FALSE FALSE   FALSE FALSE FALSE FALSE
#  [9,] FALSE FALSE   FALSE FALSE FALSE FALSE
# [10,]  TRUE FALSE   FALSE FALSE FALSE FALSE
# [11,] FALSE  TRUE   FALSE FALSE FALSE FALSE
# [12,] FALSE FALSE   FALSE FALSE FALSE FALSE
# [13,] FALSE FALSE   FALSE FALSE FALSE FALSE
# [14,] FALSE FALSE   FALSE FALSE FALSE FALSE
# [15,] FALSE FALSE   FALSE FALSE FALSE FALSE
# [16,] FALSE FALSE   FALSE FALSE FALSE FALSE
# [17,] FALSE FALSE   FALSE FALSE FALSE FALSE
# [18,] FALSE FALSE   FALSE FALSE FALSE FALSE
# [19,] FALSE FALSE   FALSE FALSE FALSE FALSE
# [20,] FALSE FALSE   FALSE FALSE FALSE FALSE
# ...

# %%
#Do all the attributes are in the most suitable data type? Make the changes you find necessary

data <- read.csv("/kaggle/input/new-york-air-quality/airquality.csv")

df <- data.frame(data)

#df["data_valuemessage"]<- list(as.integer())

df$Wind <- as.integer(df$Wind)

df
# Out:
#     Ozone Solar.R Wind Temp Month Day
# 1    41   190      7   67   5      1
# 2    36   118      8   72   5      2
# 3    12   149     12   74   5      3
# 4    18   313     11   62   5      4
# 5    NA    NA     14   56   5      5
# 6    28    NA     14   66   5      6
# 7    23   299      8   65   5      7
# 8    19    99     13   59   5      8
# 9     8    19     20   61   5      9
# 10   NA   194      8   69   5     10
# 11    7    NA      6   74   5     11
# 12   16   256      9   69   5     12
# 13   11   290      9   66   5     13
# 14   14   274     10   68   5     14
# 15   18    65     13   58   5     15
# 16   14   334     11   64   5     16
# 17   34   307     12   66   5     17
# 18    6    78     18   57   5     18
# 19   30   322     11   68   5     19
# 20   11    44      9   62   5     20
# 21    1     8      9   59   5     21
# 22   11   320     16   73   5     22
# 23    4    25      9   61   5     23
# 24   32    92     12   61   5     24
# ...

# %%
#What period of the year do these records refer to?

data <- read.csv("/kaggle/input/new-york-air-quality/airquality.csv")

df <- data.frame(data)

frecuencias <- data.frame(table(df$Month))
moda <- frecuencias[which.max(frecuencias$Freq),1]

paste( moda)
# Out:
# [1] "5"

# %%
#Load the package dplyr and save the data set in a table data frame format.

data <- read.csv("/kaggle/input/new-york-air-quality/airquality.csv")

head(data)
# Out:
#   Ozone Solar.R Wind Temp Month Day
# 1 41    190      7.4 67   5     1
# 2 36    118      8.0 72   5     2
# 3 12    149     12.6 74   5     3
# 4 18    313     11.5 62   5     4
# 5 NA     NA     14.3 56   5     5
# 6 28     NA     14.9 66   5     6

# %%
#Select the days in May with a temperature above 70 Fahrenheit.

data <- read.csv("/kaggle/input/new-york-air-quality/airquality.csv")

filter(data,Temp > 70,Month == 5)
# Out:
#   Ozone Solar.R Wind Temp Month Day
# 1  36   118      8.0 72   5      2
# 2  12   149     12.6 74   5      3
# 3   7    NA      6.9 74   5     11
# 4  11   320     16.6 73   5     22
# 5  45   252     14.9 81   5     29
# 6 115   223      5.7 79   5     30
# 7  37   279      7.4 76   5     31

# %%
#Create a new attribute TempC which represents the temperature values in Celsius

data <- read.csv("/kaggle/input/new-york-air-quality/airquality.csv")

head( mutate(data, TempC = ((Temp-32)*(0.55)) ))
# Out:
#   Ozone Solar.R Wind Temp Month Day TempC
# 1 41    190      7.4 67   5     1   19.25
# 2 36    118      8.0 72   5     2   22.00
# 3 12    149     12.6 74   5     3   23.10
# 4 18    313     11.5 62   5     4   16.50
# 5 NA     NA     14.3 56   5     5   13.20
# 6 28     NA     14.9 66   5     6   18.70

# %%
#Inspect which were the 30 hottest days.

data <- read.csv("/kaggle/input/new-york-air-quality/airquality.csv")

head(arrange(data, desc(Temp)),30)
# Out:
#    Ozone Solar.R Wind Temp Month Day
# 1   76   203      9.7 97   8     28
# 2   84   237      6.3 96   8     30
# 3  118   225      2.3 94   8     29
# 4   85   188      6.3 94   8     31
# 5   NA   259     10.9 93   6     11
# 6   73   183      2.8 93   9      3
# 7   91   189      4.6 93   9      4
# 8   NA   250      9.2 92   6     12
# 9   97   267      6.3 92   7      8
# 10  97   272      5.7 92   7      9
# 11  NA   222      8.6 92   8     10
# 12  78   197      5.1 92   9      2
# 13  NA   291     14.9 91   7     14
# 14  96   167      6.9 91   9      1
# 15  71   291     13.8 90   6      9
# 16  89   229     10.3 90   8      8
# 17 110   207      8.0 90   8      9
# 18  85   175      7.4 89   7     10
# 19 122   255      4.0 89   8      7
# 20  77   276      5.1 88   7      7
# 21  82   213      7.4 88   7     28
# 22  NA   153      5.7 88   8     27
# 23  NA   273      6.9 87   6      8
# 24  39   323     11.5 87   6     10
# 25  79   187      5.1 87   7     19
# ...

# %%
#Inspect which were the hottest days, but also with the highest ozone values.

data <- read.csv("/kaggle/input/new-york-air-quality/airquality.csv")

head(arrange(data, desc(Ozone), desc(Temp)),30)
# Out:
#    Ozone Solar.R Wind Temp Month Day
# 1  168   238      3.4 81   8     25
# 2  135   269      4.1 84   7      1
# 3  122   255      4.0 89   8      7
# 4  118   225      2.3 94   8     29
# 5  115   223      5.7 79   5     30
# 6  110   207      8.0 90   8      9
# 7  108   223      8.0 85   7     25
# 8   97   267      6.3 92   7      8
# 9   97   272      5.7 92   7      9
# 10  96   167      6.9 91   9      1
# 11  91   189      4.6 93   9      4
# 12  89   229     10.3 90   8      8
# 13  85   188      6.3 94   8     31
# 14  85   175      7.4 89   7     10
# 15  84   237      6.3 96   8     30
# 16  82   213      7.4 88   7     28
# 17  80   294      8.6 86   7     24
# 18  79   187      5.1 87   7     19
# 19  78   197      5.1 92   9      2
# 20  78    NA      6.9 86   8      4
# 21  77   276      5.1 88   7      7
# 22  76   203      9.7 97   8     28
# 23  73   183      2.8 93   9      3
# 24  73   215      8.0 86   8     26
# 25  71   291     13.8 90   6      9
# ...

# %%
#Inspect the number of days for which there was a register for each month.

data <- read.csv("/kaggle/input/new-york-air-quality/airquality.csv")

by_cyl <- group_by(data, Day)

summarise(by_cyl, n())
# Out:
#    Day n()
# 1   1  5
# 2   2  5
# 3   3  5
# 4   4  5
# 5   5  5
# 6   6  5
# 7   7  5
# 8   8  5
# 9   9  5
# 10 10  5
# 11 11  5
# 12 12  5
# 13 13  5
# 14 14  5
# 15 15  5
# 16 16  5
# 17 17  5
# 18 18  5
# 19 19  5
# 20 20  5
# 21 21  5
# 22 22  5
# 23 23  5
# 24 24  5
# 25 25  5
# 26 26  5
# 27 27  5
# 28 28  5
# 29 29  5
# 30 30  5
# 31 31  3

# %%
#For each month, obtain the minimum and the maximum temperature registered in Celsius.

data <- read.csv("/kaggle/input/new-york-air-quality/airquality.csv")

by_cyl <- group_by(mutate(data, TempC = ((Temp-32)*(0.55)) ), Month)

summarise(by_cyl, max(TempC),min(TempC))
# Out:
#   Month max(TempC) min(TempC)
# 1 5     26.95      13.20
# 2 6     33.55      18.15
# 3 7     33.00      22.55
# 4 8     35.75      22.00
# 5 9     33.55      17.05

# %%
#Obtain the average of the following parameters by month: temperature in celsius, wind, solar
#radiation and ozone

data <- read.csv("/kaggle/input/new-york-air-quality/airquality.csv")

by_cyl <- group_by(mutate(data, TempC = ((Temp-32)*(0.55)) ), Month)

summarise(by_cyl, mean(Ozone), mean(Solar.R), mean(Wind), mean(TempC))
# Out:
#   Month mean(Ozone) mean(Solar.R) mean(Wind) mean(TempC)
# 1 5     NA                NA      11.622581  18.45161
# 2 6     NA          190.1667      10.266667  25.90500
# 3 7     NA          216.4839       8.941935  28.54677
# 4 8     NA                NA       8.793548  28.58226
# 5 9     NA          167.4333      10.180000  24.69500

# %%
#What values did you obtain regarding ozone and solar radiation attributes? Why? Make the
#necessary change so that you get the average of the registered values.

data <- read.csv("/kaggle/input/new-york-air-quality/airquality.csv")

by_cyl <- group_by(mutate(data, TempC = ((Temp-32)*(0.55)) ), Month)

summarise(by_cyl, mean(Ozone,na.rm=TRUE), mean(Solar.R,na.rm=TRUE), mean(Wind), mean(TempC))
# Out:
#   Month mean(Ozone, na.rm = TRUE) mean(Solar.R, na.rm = TRUE) mean(Wind)
# 1 5     23.61538                  181.2963                    11.622581
# 2 6     29.44444                  190.1667                    10.266667
# 3 7     59.11538                  216.4839                     8.941935
# 4 8     59.96154                  171.8571                     8.793548
# 5 9     31.44828                  167.4333                    10.180000
#   mean(TempC)
# 1 18.45161
# 2 25.90500
# 3 28.54677
# 4 28.58226
# 5 24.69500
